# %%
from scaling import Scaling

img = Scaling(
    img_dir=r"C:\Users\chiny\OneDrive - Nanyang Technological University\Internships\AY23 DSO Summer\Classification of RF Project\toexport\toexport\testing_env\images",
    labels_dir=r"C:\Users\chiny\OneDrive - Nanyang Technological University\Internships\AY23 DSO Summer\Classification of RF Project\toexport\toexport\testing_env\labels"
    )

import glob
for l in glob.glob(img.img_dir + "\*.png"):
    img.obtain_info(img_path=l)
    img.slice_img()
    img.save_imgs(dir=r"C:\Users\chiny\OneDrive - Nanyang Technological University\Internships\AY23 DSO Summer\Classification of RF Project\toexport\toexport\testing_env\images_new")
    data = img.slice_labels(tolerance=5)
    img.write_files(inputs = data, path_dir=r"C:\Users\chiny\OneDrive - Nanyang Technological University\Internships\AY23 DSO Summer\Classification of RF Project\toexport\toexport\testing_env\new_labels")

# %%
from drawing import Drawing

image = Drawing.show_box(
    image_path=r"C:\Users\chiny\OneDrive - Nanyang Technological University\Internships\AY23 DSO Summer\Classification of RF Project\toexport\toexport\testing_env\images_new\138847877310877881_bw_25E+6_6.png",
    label_path=r"C:\Users\chiny\OneDrive - Nanyang Technological University\Internships\AY23 DSO Summer\Classification of RF Project\toexport\toexport\testing_env\new_labels\138847877310877881_bw_25E+6_6.txt"
)

display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=109x128>

# %%
image = Drawing.show_box(
    image_path=img.img_path,
    label_path=img.labels_path
)

display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=878x128>
